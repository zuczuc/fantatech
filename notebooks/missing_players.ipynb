# %%
# %load_ext autoreload
# %autoreload 2

import sys

sys.path.append('/Users/pnecchi/Documents/Projects/fantatech/')

from fantatech.startup import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
ids_p = set(df.loc[(df['Season'] == 2019) & (df['Ruolo'] == 'P'), 'Id'])
ids_d = set(df.loc[(df['Season'] == 2019) & (df['Ruolo'] == 'D'), 'Id'])
ids_c = set(df.loc[(df['Season'] == 2019) & (df['Ruolo'] == 'C'), 'Id'])
ids_a = set(df.loc[(df['Season'] == 2019) & (df['Ruolo'] == 'A'), 'Id'])

# %%
p = player

# %% [markdown]
# # Players bought

# %%
players_bought = set([
    player.musacchio, player.hetemaj, player.ibanez, player.nestorovski, player.ayhan,
    player.agudelo, player.romero, player.piccini, player.viola, player.rafael, player.nandez, 
    player.barella, player.samir, player.laurini, player.djimsiti, player.kurtic, player.insigne,
    player.krunic, player.dragus, player.caldirola, player.iacoponi, player.faraoni, player.malinovskyi, 
    player.karamoh, player.damsgaard, player.defrel, player.vlahovic, player.golemic, 
    player.correa, player.poli, player.bonucci, player.conti, player.di_lorenzo, player.gervinho, 
    player.lucas_leiva, player.luis_alberto, player.chiesa, player.lapadula, player.hysaj, 
    player.barreca, player.elmas, player.cristante, player.gabbia, player.kulusevski, player.bourabia, 
    player.orsolini, player.dijks, p.sturaro, p.nainggolan, p.mario_rui, p.ferrari_g, p.skorupski, 
    player.bastoni, player.rispoli, p.veretout, p.pellegrini_lo, p.chiellini, p.verre, p.ribery, 
    p.lazovic, p.mkhitaryan, p.pezzella_ger, p.vignato, p.candreva, p.galabinov, p.kolarov, 
    p.magallan, p.freuler, p.hernani, p.soriano, p.pulgar, p.carles_perez, p.caprari, p.denswil, p.bentancur, 
    p.hickey, p.barba, p.donnarumma_g, p.vidal, p.barrow, p.cataldi, p.colley_e, p.criscito, 
    p.mertens, p.marlon, p.bruno_alves, p.stryger_larsen, p.szczesny, p.duncan, p.castrovilli, 
    p.palacio, p.lykogiannis, p.bakayoko, p.dzeko, p.marin, p.skov_olsen, p.quagliarella, 
    p.politano, p.ekdal, p.pasalic, p.immobile, p.muriel, p.acerbi, p.consigli, p.toljan, p.smalling, 
    p.messias, p.spinazzola, p.martinez_l, p.caputo, p.strakosha, p.ansaldi, p.dambrosio, p.letizia, 
    p.miguel_veloso, p.dimarco, p.demiral, p.obiang, p.perin, p.ruiz, p.amrabat, p.milinkovic_savic, 
    p.gabbiadini, p.alex_sandro, p.biraghi, p.milenkovic, p.belotti, p.young, p.bani, p.bruno_peres, 
    p.lirola, p.milenkovic, p.bonaventura, p.jankto, p.pellegrini_lu, p.rabiot, p.dragowski, p.kouame, p.kyriakopoulos,
    p.nuytinck, p.kumbulla, p.diawara, p.izzo, p.pjaca, p.calhanoglu, p.mancini, p.skriniar, p.djidji, 
    p.castillejo, p.sanchez, p.zapata_d, p.brozovic, p.zaccagni, p.cragno, p.ter_avest, p.augello, p.bremer, 
    p.darmian, p.luiz_felipe, p.palomino, p.toloi, p.caceres, p.buffon, p.keita_b, p.ceppitelli, p.parolo, 
    p.ronaldo, p.traore_hj, p.tripaldelli, p.silvestri, p.handanovic, p.sportiello, p.ilicic, p.kalinic, 
    p.musso, p.de_vrij, p.kucka, p.tonali, p.gollini, p.miranchuk, p.chabot, p.tomiyasu, p.zaniolo, p.danilo_lar, 
    p.de_paul, p.cuadrado, p.romagnoli, p.romero, p.vojvoda, p.rebic, p.reina, p.cornelius, p.milik, p.boga, 
    p.bonazzoli, p.callejon, p.gagliardini, p.saponara, p.cyprien, p.berardi, p.boga, p.gosens, p.ibrahimovic, 
    p.morata, p.gagliolo, p.marusic, p.ramsey, p.verdi, p.locatelli, p.borja_valero, p.pandev, p.arthur, 
    p.linetty, p.meret, p.pedro, p.lobotka, p.godin, p.rog, p.audero, p.pegolo, p.lukaku, p.yoshida, 
    p.sensi, p.ramirez, p.kessie, p.schouten, p.lammers, p.muldur, p.mckennie, p.simeone, 
    p.hakimi, p.hernandez_t, p.dybala, p.joao_pedro, p.simy, p.gomez, p.de_ligt, p.manolas
     
 ])

# %% [markdown]
# # Portieri

# %%
show_players_stats(ids_p - players_bought, years=2019, nrows=10)
# Out:
# <style  type="text/css" >
# #T_637c5de2_1655_11eb_8806_acde48001122row0_col4,#T_637c5de2_1655_11eb_8806_acde48001122row2_col4,#T_637c5de2_1655_11eb_8806_acde48001122row4_col4,#T_637c5de2_1655_11eb_8806_acde48001122row4_col5,#T_637c5de2_1655_11eb_8806_acde48001122row6_col4,#T_637c5de2_1655_11eb_8806_acde48001122row6_col5,#T_637c5de2_1655_11eb_8806_acde48001122row8_col5{
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  lightgray;
#         }#T_637c5de2_1655_11eb_8806_acde48001122row0_col5{
#             background-color:  #f1f9ac;
#             color:  #000000;
#         }#T_637c5de2_1655_11eb_8806_acde48001122row0_col6{
#             background-color:  #bde379;
#             color:  #000000;
#         }#T_637c5de2_1655_11eb_8806_acde48001122row0_col7{
#             background-color:  #08306b;
#             color:  #f1f1f1;
# ...

# %% [markdown]
# # Difensori

# %%
show_players_stats(ids_d - players_bought, years=2019, nrows=20)
# Out:
# <style  type="text/css" >
# #T_63af60e8_1655_11eb_8806_acde48001122row0_col4,#T_63af60e8_1655_11eb_8806_acde48001122row1_col4,#T_63af60e8_1655_11eb_8806_acde48001122row1_col5,#T_63af60e8_1655_11eb_8806_acde48001122row4_col4,#T_63af60e8_1655_11eb_8806_acde48001122row4_col5,#T_63af60e8_1655_11eb_8806_acde48001122row6_col4,#T_63af60e8_1655_11eb_8806_acde48001122row6_col5,#T_63af60e8_1655_11eb_8806_acde48001122row7_col4,#T_63af60e8_1655_11eb_8806_acde48001122row7_col5,#T_63af60e8_1655_11eb_8806_acde48001122row9_col4,#T_63af60e8_1655_11eb_8806_acde48001122row9_col5,#T_63af60e8_1655_11eb_8806_acde48001122row11_col4,#T_63af60e8_1655_11eb_8806_acde48001122row13_col4,#T_63af60e8_1655_11eb_8806_acde48001122row13_col5,#T_63af60e8_1655_11eb_8806_acde48001122row16_col4{
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  lightgray;
# ...

# %% [markdown]
# # Centrocampisti

# %%
show_players_stats(ids_c - players_bought, years=2019, nrows=20)
# Out:
# <style  type="text/css" >
# #T_63e22f28_1655_11eb_8806_acde48001122row0_col4,#T_63e22f28_1655_11eb_8806_acde48001122row5_col4,#T_63e22f28_1655_11eb_8806_acde48001122row5_col5,#T_63e22f28_1655_11eb_8806_acde48001122row6_col4,#T_63e22f28_1655_11eb_8806_acde48001122row8_col4,#T_63e22f28_1655_11eb_8806_acde48001122row8_col5,#T_63e22f28_1655_11eb_8806_acde48001122row10_col4,#T_63e22f28_1655_11eb_8806_acde48001122row11_col4,#T_63e22f28_1655_11eb_8806_acde48001122row11_col5,#T_63e22f28_1655_11eb_8806_acde48001122row12_col4,#T_63e22f28_1655_11eb_8806_acde48001122row12_col5,#T_63e22f28_1655_11eb_8806_acde48001122row14_col4,#T_63e22f28_1655_11eb_8806_acde48001122row14_col5,#T_63e22f28_1655_11eb_8806_acde48001122row17_col4,#T_63e22f28_1655_11eb_8806_acde48001122row18_col4,#T_63e22f28_1655_11eb_8806_acde48001122row18_col5{
#             background-color:  #000000;
#             color:  #f1f1f1;
#             background-color:  lightgray;
# ...

# %% [markdown]
# # Attaccanti

# %%
show_players_stats(ids_a - players_bought, years=2019, nrows=20)
# Out:
# <style  type="text/css" >
# #T_6414cc58_1655_11eb_8806_acde48001122row0_col4{
#             background-color:  #f88c51;
#             color:  #000000;
#         }#T_6414cc58_1655_11eb_8806_acde48001122row0_col5{
#             background-color:  #d1ec86;
#             color:  #000000;
#         }#T_6414cc58_1655_11eb_8806_acde48001122row0_col6,#T_6414cc58_1655_11eb_8806_acde48001122row13_col4{
#             background-color:  #f7fcb4;
#             color:  #000000;
#         }#T_6414cc58_1655_11eb_8806_acde48001122row0_col7{
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }#T_6414cc58_1655_11eb_8806_acde48001122row1_col4{
#             background-color:  #f99355;
#             color:  #000000;
#         }#T_6414cc58_1655_11eb_8806_acde48001122row1_col5{
#             background-color:  #138c4a;
#             color:  #000000;
#         }#T_6414cc58_1655_11eb_8806_acde48001122row1_col6{
#             background-color:  #fffdbc;
# ...
