# %%
# %load_ext autoreload
# %autoreload 2

import sys

sys.path.append('/Users/pnecchi/Documents/Projects/fantatech/')

from fantatech.startup import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Team builder

# %%
build_team(
    [
        (player.caldirola, 8), 
        (player.bonucci, 32), 
        (player.chiesa, 40), 
        (player.leris, 1), 
        (player.gabbia, 1), 
        (player.verre, 8), 
        (player.okaka, 5), 
        (player.pezzella_ger, 13), 
        (player.oliva, 1), 
        (player.hernani, 6), 
        (player.barrow, 35), 
        (player.klavan, 2), 
        (player.schiattarella, 1), 
        (player.toljan, 13), 
        (player.strakosha, 45), 
        (player.sottil, 5), 
        (player.coulibaly, 1), 
        (player.biraghi, 15), 
        (player.ranocchia, 1), 
        (player.diawara, 3), 
        (player.darmian, 6),
        (player.traore_hj, 3),
        (player.reina, 2),
        (player.berardi, 59),
        (player.linetty, 5),
        (player.lobotka, 1),
        (player.kessie, 21),
        (player.joao_pedro, 18),
        (player.hakimi, 19),
        (player.simy, 2),
        (player.manolas, 9),

        
    ], 
#     target_formations=[
#         formations.Formation._433, 
#         formations.Formation._4231,
#         formations.Formation._442, 
#         formations.Formation._343,

#     ]
)
# Out:
# <font size="+1"><b>Team Builder</b></font>
#        Budget  Spent  Left  Number of players  TotFvExtra
# Recap     400    381    19                 31         4.1
# <style  type="text/css" >
# #T_0c95cb4e_1655_11eb_a1b1_acde48001122row0_col2{
#             background-color:  #fff1ea;
#             color:  #000000;
#         }#T_0c95cb4e_1655_11eb_a1b1_acde48001122row1_col2{
#             background-color:  #fdd2bf;
#             color:  #000000;
#         }#T_0c95cb4e_1655_11eb_a1b1_acde48001122row2_col2{
#             background-color:  #fdc5ae;
#             color:  #000000;
#         }#T_0c95cb4e_1655_11eb_a1b1_acde48001122row3_col2{
#             background-color:  #fee8dd;
#             color:  #000000;
#         }#T_0c95cb4e_1655_11eb_a1b1_acde48001122row4_col2{
#             background-color:  #fff5f0;
#             color:  #000000;
#         }#T_0c95cb4e_1655_11eb_a1b1_acde48001122row5_col2{
#             background-color:  #67000d;
#             color:  #f1f1f1;
# ...
